# %%
import pandas as pd

# %%
header =  pd.read_csv("C:\\Users\\Owner\\Desktop\\AMS_DATA\\header\\ams__header_2020__202009291500_part_0.csv")
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_17416\2079392627.py:1: DtypeWarning: Columns (25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   header =  pd.read_csv("C:\\Users\\Owner\\Desktop\\AMS_DATA\\header\\ams__header_2020__202009291500_part_0.csv")

# %%
header.head(1)
# Out:
#    identifier carrier_code vessel_country_code           vessel_name  \
# 0   202001060         SWOE                  US  PRESIDENT EISENHOWER
#
#       port_of_unlading estimated_arrival_date  \
# 0  Oakland, California             2019-08-09
#
#   foreign_port_of_lading_qualifier      foreign_port_of_lading  \
# 0          Schedule K Foreign Port  Shanghai ,China (Mainland)
#
#    manifest_quantity manifest_unit  ...  secondary_notify_party_2  \
# 0                 18           PKG  ...                       NaN
#
#   secondary_notify_party_3  secondary_notify_party_4 secondary_notify_party_5  \
# 0                      NaN                       NaN                      NaN
#
#   secondary_notify_party_6 secondary_notify_party_7 secondary_notify_party_8  \
# 0                      NaN                      NaN                      NaN
#
#   secondary_notify_party_9 secondary_notify_party_10 actual_arrival_date
# ...

# %%
header = header.sort_values("port_of_unlading")

# %%
header.head()
# Out:
#             identifier carrier_code vessel_country_code vessel_name  \
# 2543994  2020022042760         CHSL                  LR   NYK MARIA
# 2544295  2020022042761         CHSL                  LR   NYK MARIA
# 2892055  2020022633538         CHSL                  LR   NYK MARIA
# 2858955    20200226487         CHSL                  LR   NYK MARIA
# 1726087  2020021055530         MLCW                  TW  EVER LOGIC
#
#         port_of_unlading estimated_arrival_date  \
# 2543994             2791             2019-11-22
# 2544295             2791             2019-11-22
# 2892055             2791             2019-11-22
# 2858955             2791             2019-11-22
# 1726087             2791             2020-01-24
#
#         foreign_port_of_lading_qualifier    foreign_port_of_lading  \
# 2543994          Schedule K Foreign Port               Callao,Peru
# 2544295          Schedule K Foreign Port               Callao,Peru
# ...

# %%
header['vessel_date'] = header['vessel_name'] + header['actual_arrival_date']

# %%
header = header.sort_values(by='vessel_date')

# %%
header['voyage_id'] = header['vessel_date'].rank(method='dense').astype('int')

# %%
header[100:140]
# Out:
#             identifier carrier_code vessel_country_code vessel_name  \
# 4388438   202003311438         SAIJ                  SG     9218674
# 4449100  2020033162089         SAIJ                  SG     9218674
# 4449098  2020033162087         SAIJ                  SG     9218674
# 4449097  2020033162086         SAIJ                  SG     9218674
# 4449093  2020033162082         SAIJ                  SG     9218674
# 4449091  2020033162080         SAIJ                  SG     9218674
# 4449090  2020033162079         SAIJ                  SG     9218674
# 4387098     2020033190         SAIJ                  SG     9218674
# 4387099     2020033191         SAIJ                  SG     9218674
# 1829860     2020020656         SAIJ                  SG     9218674
# 4387097     2020033189         SAIJ                  SG     9218674
# 4449099  2020033162088         SAIJ                  SG     9218674
# 3901573  2020032845213         SAIJ                  SG     9218674
# ...
